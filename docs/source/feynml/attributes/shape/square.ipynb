# %% [markdown]
# # square

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_vertex("square")
# Out:
# tikz:
# <wand.image.Image: c80cfc8 'PDF' (79x79)>
# pyx:
# <wand.image.Image: 162197d 'PDF' (157x157)>
# feynmp:
# <wand.image.Image: 2b8bd15 'PDF' (180x111)>
# feynman:
# dot:
# <wand.image.Image: 6f8e222 'PDF' (303x251)>
# asciipdf:
# <wand.image.Image: 433a80c 'PDF' (166x332)>
# unicodepdf:
# <wand.image.Image: 496cc8f 'PDF' (477x176)>
