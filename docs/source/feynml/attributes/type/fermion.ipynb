# %% [markdown]
# # Fermion

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("fermion")
# Out:
# Pyx:
# <wand.image.Image: 2d48aca 'PDF' (157x14)>
# Tikz:
# <wand.image.Image: e5aad8b 'PDF' (167x167)>
# Feynmp:
# <wand.image.Image: cad1aa2 'PDF' (180x111)>
# Dot:
# <wand.image.Image: 3e72e76 'PDF' (476x73)>
# ASCIIPDF:
# <wand.image.Image: 0006855 'PDF' (108x33)>
# MPL:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pyfeyn2.render.all import AllRender
# ----> 2 ar = AllRender().demo_propagator("fermion")
#
# File ~/data/de.neuwirthinformatik.Alexander/Development/git/pyfeyn2/pyfeyn2/render/render.py:56, in Render.demo_propagator(self, d, show)
#      54 fd.legs.extend([l1, l2])
#      55 self.set_feynman_diagram(fd)
# ---> 56 self.render(show=show)
#
# File ~/data/de.neuwirthinformatik.Alexander/Development/git/pyfeyn2/pyfeyn2/render/all.py:78, in AllRender.render(self, file, show, subfigure, resolution, width, height)
# ...
