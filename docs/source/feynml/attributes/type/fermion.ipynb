# %% [markdown]
# # fermion

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("fermion")
# Out:
# tikz:
# <wand.image.Image: 74a6407 'PDF' (158x23)>
# pyx:
# <wand.image.Image: 718347d 'PDF' (315x46)>
# feynmp:
# <wand.image.Image: f49aa2e 'PDF' (180x111)>
# feynman:
# dot:
# <wand.image.Image: 14d5ec4 'PDF' (531x51)>
# asciipdf:
# <wand.image.Image: 8b227ff 'PDF' (332x332)>
# unicodepdf:
# <wand.image.Image: b88d9e4 'PDF' (477x60)>
