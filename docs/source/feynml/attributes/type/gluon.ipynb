# %% [markdown]
# # Gluon

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("gluon")
# Out:
# Pyx:
# <wand.image.Image: d28a30f 'PDF' (39x3)>
# Tikz:
# <wand.image.Image: 87298c6 'PDF' (88x88)>
# Feynmp:
# <wand.image.Image: 0a10637 'PDF' (180x111)>
# Dot:
# <wand.image.Image: 6d659ae 'PDF' (276x90)>
# ASCIIPDF:
# <wand.image.Image: f405c97 'PDF' (25x17)>
# MPL:
