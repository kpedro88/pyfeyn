# %% [markdown]
# # phantom
#
# Phantom is used as a utility connection and rendered as nothing.

# %%
import pyfeyn2
pyfeyn2.__version__
# Out:
# '2.2.6.6'

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("phantom")
# Out:
# tikz:
# <wand.image.Image: 0314440 'PDF' (157x22)>
# pyx:
# <wand.image.Image: 077a037 'PDF' (107x25)>
# feynmp:
# <wand.image.Image: 46e7270 'PDF' (180x111)>
# feynman:
# dot:
# <wand.image.Image: 07a4236 'PDF' (531x51)>
# asciipdf:
# <wand.image.Image: adfe2ba 'PDF' (166x282)>
# unicodepdf:
# <wand.image.Image: 5cbde8a 'PDF' (477x13)>
