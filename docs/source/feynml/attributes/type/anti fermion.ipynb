# %% [markdown]
# # anti fermion

# %%
from pyfeyn2.render.all import AllRender
ar = AllRender().demo_propagator("anti fermion")
# Out:
# tikz:
# <wand.image.Image: 3d0dddb 'PDF' (158x23)>
# pyx:
# <wand.image.Image: addb178 'PDF' (315x46)>
# feynmp:
# <wand.image.Image: 4ebdc0d 'PDF' (180x111)>
# feynman:
# dot:
# dot failed:
# Traceback (most recent call last):
#   File "/home/apn/git/pyfeyn2/pyfeyn2/render/all.py", line 84, in render
#     render(fd).render(dirpath + "/" + name + ".pdf", **dynarg)
#   File "/home/apn/git/pyfeyn2/pyfeyn2/render/latex/dot.py", line 78, in __init__
#     self.set_feynman_diagram(fd)
#   File "/home/apn/git/pyfeyn2/pyfeyn2/render/latex/dot.py", line 82, in set_feynman_diagram
#     self.src_dot = feynman_to_dot(
#   File "/home/apn/git/pyfeyn2/pyfeyn2/interface/dot.py", line 61, in feynman_to_dot
#     thestyle = styler(fd, p)
#   File "/home/apn/git/pyfeyn2/pyfeyn2/render/latex/dot.py", line 38, in stylize_connect
#     style = 'style="{}",texmode="raw"'.format(map_feyn_to_tikz[lname])
# KeyError: 'anti fermion'
#
# asciipdf:
# <wand.image.Image: 5c7abf4 'PDF' (332x332)>
# unicodepdf:
# ...
